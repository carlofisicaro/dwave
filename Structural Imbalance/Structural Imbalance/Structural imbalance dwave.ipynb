# %% [markdown]
# # Structural Imbalance with the D-Wave System

# %% [markdown]
# ## Imports

# %%
import networkx as nx
import random
from dwave.system.samplers import DWaveSampler
from dwave.system.composites import EmbeddingComposite
import dwave_networkx as dnx
from helpers.draw import draw
from dwave_structural_imbalance_demo.mmp_network.loader import *
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Formulating the Problem for a D-Wave System

# %% [markdown]
# D-Wave systems solve Ising problems: given $N$ variables $s_1,...,s_N$, where each variable $s_i$ can have values $-1$ or $+1$, the system finds assignments of values that minimize
#
#   $\sum_{i=1}^N h_i s_i +
#   \sum_{i<j}^N J_{i,j} s_i s_j$,
#
# where $h_i$ and $J_{i,j}$ are configurable (linear and quadratic) coefficients.
#
# In our case, variables $s_i$ can represent people, with values $-1,+1$ denoting a person's assignment to one of the two sets we want to divide the social network into. If we set $J_{i,j}$ to $-1$ for friendly $s_is_j$ pairs and $+1$ for hostile pairs, their multiplication takes values
#
# $J_{i,j} s_i s_j=
# \begin{cases}
#       -1 & \text{friends in same set (} s_i=s_j \text{) or enemies in different sets ($s_i \ne s_j$)} \\
#       +1 & \text{friends in different sets ($s_i \ne s_j$) or enemies in same set ($s_i=s_j$)}
# \end{cases}
# $
#
# The summation $\sum_{i<j}^N J_{i,j} s_i s_j$ now decrements when an assignment contributes to balance and increments when it contributes to frustration.
#
# The quantum computer finds partitions (assignments of $s_i$) that minimize frustration.

# %% [markdown]
# ## A Real-World Example

# %% [markdown]
# A study of the violent extremist network in Syria found that the network was balanced in 2012. However, in 2013 an increase in active groups in the Syrian theatre changed the existing landscape significantly.

# %%
sampler = EmbeddingComposite(DWaveSampler(endpoint='https://cloud.dwavesys.com/sapi', \
                                          token='DEV-bc7705c39af039eacfdfe447749da106f22ab4f2', \
                                          solver='DW_2000Q_2_1'))

# %%
G = global_signed_social_network()

# %%
# Select the Syria subregion by creating subgraph S from the full data set G
syria_groups = set()
for v, data in G.nodes(data=True):
    if 'map' not in data:
        continue
    if data['map'] in {'Syria', 'Aleppo'}:
        syria_groups.add(v)
S = G.subgraph(syria_groups)

# Filter by year
year = 2013
filtered_edges = ((u, v) for u, v, a in S.edges(data=True) if a['event_year'] <= year)
S = S.edge_subgraph(filtered_edges)

# %%
position = draw(S)
# Out:
#   <div class="bk-root" id="0301482f-d1dd-4b39-92a4-97be4f186c6b" data-root-id="4219"></div>

# %%
# Return a good partition of the Syrian 2013 network and its frustrated edges 
imbalance, bicoloring = dnx.structural_imbalance(S, sampler)
# Annotate the network with the returned frustrated edges and node sets
for edge in S.edges:
    S.edges[edge]['frustrated'] = edge in imbalance
for node in S.nodes:
    S.nodes[node]['color'] = bicoloring[node]

# %% [markdown]
# Redraw the network with the previous node positioning: nodes are now bicolored and dashed lines indicate frustrated edges.

# %%
draw(S, position);
# Out:
#   <div class="bk-root" id="6a603c89-5aca-4000-acdd-6be6d0041155" data-root-id="4629"></div>

# %% [markdown]
# Redraw the network with a new positioning that separates the two sets.

# %%
# Frustrated edges now stand out
draw(S);
# Out:
#   <div class="bk-root" id="542bec4d-4549-4cde-979f-cdf624630445" data-root-id="3736"></div>

# %% [markdown]
# ## What about a classical graph algorithm?

# %%
import dimod
solver = dimod.ExactSolver()

# %%
# Return a good partition of the Syrian 2013 network and its frustrated edges 
imbalance, bicoloring = dnx.structural_imbalance(G, solver)
# Annotate the network with the returned frustrated edges and node sets
for edge in S.edges:
    S.edges[edge]['frustrated'] = edge in imbalance
for node in S.nodes:
    S.nodes[node]['color'] = bicoloring[node]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-35730ad0000f> in <module>
#       1 # Return a good partition of the Syrian 2013 network and its frustrated edges
# ----> 2 imbalance, bicoloring = dnx.structural_imbalance(G, solver)
#       3 # Annotate the network with the returned frustrated edges and node sets
#       4 for edge in S.edges:
#       5     S.edges[edge]['frustrated'] = edge in imbalance
#
# <//anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-819> in structural_imbalance(S, sampler, **sampler_args)
#
# //anaconda3/lib/python3.7/site-packages/dwave_networkx/utils/decorators.py in _binary_quadratic_model_sampler(f, *args, **kw)
#     148
#     149         # now run the function and return the results
# --> 150         return f(*new_args, **kw)
#     151     return _binary_quadratic_model_sampler
#
# //anaconda3/lib/python3.7/site-packages/dwave_networkx/algorithms/social.py in structural_imbalance(S, sampler, **sampler_args)
#     112
#     113     # use the sampler to find low energy states
# --> 114     response = sampler.sample_ising(h, J, **sampler_args)
#     115
#     116     # we want the lowest energy sample
#
# //anaconda3/lib/python3.7/site-packages/dimod/core/sampler.py in sample_ising(self, h, J, **parameters)
#     215         """
#     216         bqm = BinaryQuadraticModel.from_ising(h, J)
# --> 217         return self.sample(bqm, **parameters)
#     218
#     219     @samplemixinmethod
#
# //anaconda3/lib/python3.7/site-packages/dimod/decorators.py in _index_label(sampler, bqm, **kwargs)
#      67         mapping = {v: i for i, v in iteritems(inverse_mapping)}
#      68
# ---> 69         response = f(sampler, bqm.relabel_variables(mapping, inplace=False), **kwargs)
#      70
#      71         # unapply the relabeling
#
# //anaconda3/lib/python3.7/site-packages/dimod/reference/samplers/exact_solver.py in sample(self, bqm)
#     117                 yield sample.copy(), float(energy) + off
#     118
# --> 119         samples, energies = zip(*iter_samples())
#     120
#     121         response = SampleSet.from_samples(np.array(samples, dtype='int8'), Vartype.BINARY, energies)
#
# //anaconda3/lib/python3.7/site-packages/dimod/reference/samplers/exact_solver.py in iter_samples()
#     113                 # the energy delta for the single bit flip, don't have time, pull requests
#     114                 # appreciated!
# --> 115                 energy = sample.dot(M).dot(sample.transpose())
#     116
#     117                 yield sample.copy(), float(energy) + off
#
# KeyboardInterrupt:
